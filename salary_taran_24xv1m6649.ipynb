# %%
import pandas as pd

data = {
    "Experience": [1,2,3,4,6,7,9,11,13,15],
    "Age": [22,23,25,26,28,30,33,36,40,45],
    "Salary": [25000,28000,30000,35000,42000,48000,55000,62000,70000,85000]
}

df = pd.DataFrame(data)
df
# Out:
#    Experience  Age  Salary
# 0           1   22   25000
# 1           2   23   28000
# 2           3   25   30000
# 3           4   26   35000
# 4           6   28   42000
# 5           7   30   48000
# 6           9   33   55000
# 7          11   36   62000
# 8          13   40   70000
# 9          15   45   85000

# %%
df.to_csv("Salary_Data.csv", index=False)
print("CSV CREATED")
# Out:
# CSV CREATED

# %%
salary = pd.read_csv("Salary_Data.csv")
salary.head()
# Out:
#    Experience  Age  Salary
# 0           1   22   25000
# 1           2   23   28000
# 2           3   25   30000
# 3           4   26   35000
# 4           6   28   42000

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import statsmodels.api as sm
import statsmodels.formula.api as smf
salary = pd.read_csv("Salary_Data.csv")
#salary.set_index('YearsExperience',inplace=True)

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import statsmodels.api as sm
import statsmodels.formula.api as smf

# %%
salary = pd.read_csv("Salary_Data.csv")

# %%
salary
# Out:
#    Experience  Age  Salary
# 0           1   22   25000
# 1           2   23   28000
# 2           3   25   30000
# 3           4   26   35000
# 4           6   28   42000
# 5           7   30   48000
# 6           9   33   55000
# 7          11   36   62000
# 8          13   40   70000
# 9          15   45   85000

# %%
X= salary.drop('Salary',axis=1)
X.head()
# Out:
#    Experience  Age
# 0           1   22
# 1           2   23
# 2           3   25
# 3           4   26
# 4           6   28

# %%
Y=salary[['Salary']]
Y.head()
# Out:
#    Salary
# 0   25000
# 1   28000
# 2   30000
# 3   35000
# 4   42000

# %%
X = sm.add_constant(X) # adding a constant

model = sm.OLS(Y, X).fit()
predictions = model.predict(X)


linearModel1=sm.OLS(Y,X).fit()

# %%
print(linearModel1.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                 Salary   R-squared:                       0.996
# Model:                            OLS   Adj. R-squared:                  0.994
# Method:                 Least Squares   F-statistic:                     793.6
# Date:                Sun, 30 Nov 2025   Prob (F-statistic):           5.61e-09
# Time:                        23:03:15   Log-Likelihood:                -85.495
# No. Observations:                  10   AIC:                             177.0
# Df Residuals:                       7   BIC:                             177.9
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -1.655e+04   1.09e+04     -1.523      0.172   -4.22e+04    9142.884
# ...
