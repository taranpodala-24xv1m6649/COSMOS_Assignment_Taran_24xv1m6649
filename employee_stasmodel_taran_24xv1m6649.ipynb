# %%
import pandas as pd

data = {
    "Experience": [1, 2, 3, 4, 5, 7, 10, 12, 15, 20],
    "Age":        [22, 23, 25, 26, 28, 30, 35, 38, 42, 50],
    "Salary":     [25000, 28000, 30000, 35000, 38000, 45000, 60000, 65000, 75000, 90000]
}

df = pd.DataFrame(data)
df
# Out:
#    Experience  Age  Salary
# 0           1   22   25000
# 1           2   23   28000
# 2           3   25   30000
# 3           4   26   35000
# 4           5   28   38000
# 5           7   30   45000
# 6          10   35   60000
# 7          12   38   65000
# 8          15   42   75000
# 9          20   50   90000

# %%
df.to_csv("employee_data1.csv", index=False)
print("CSV file created successfully!")
# Out:
# CSV file created successfully!

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import statsmodels.api as sm
import statsmodels.formula.api as smf
emp = pd.read_csv("employee_data1.csv")

# %%
pd.set_option('display.max_rows', None)

# %%
emp.head()
# Out:
#    Experience  Age  Salary
# 0           1   22   25000
# 1           2   23   28000
# 2           3   25   30000
# 3           4   26   35000
# 4           5   28   38000

# %%
print(emp)
# Out:
#    Experience  Age  Salary
# 0           1   22   25000
# 1           2   23   28000
# 2           3   25   30000
# 3           4   26   35000
# 4           5   28   38000
# 5           7   30   45000
# 6          10   35   60000
# 7          12   38   65000
# 8          15   42   75000
# 9          20   50   90000

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import statsmodels.api as sm
import statsmodels.formula.api as smf

emp = pd.read_csv("employee_data1.csv")
emp.head()
# Out:
#    Experience  Age  Salary
# 0           1   22   25000
# 1           2   23   28000
# 2           3   25   30000
# 3           4   26   35000
# 4           5   28   38000

# %%
Xvar = emp.drop('Salary', axis=1)   # ✅ correct
Xvar.head()
# Out:
#    Experience  Age
# 0           1   22
# 1           2   23
# 2           3   25
# 3           4   26
# 4           5   28

# %%
Yvar = emp[['Salary']]
Yvar.head()
# Out:
#    Salary
# 0   25000
# 1   28000
# 2   30000
# 3   35000
# 4   38000

# %%
#OLS - Ordinary least squares
linearModel1=sm.OLS(Yvar,Xvar).fit()

# %%
print(linearModel1.summary())
# Out:
#                                  OLS Regression Results
# ...
# Dep. Variable:                 Salary   R-squared (uncentered):                   0.999
# Model:                            OLS   Adj. R-squared (uncentered):              0.999
# Method:                 Least Squares   F-statistic:                              4441.
# Date:                Sun, 30 Nov 2025   Prob (F-statistic):                    6.56e-13
# Time:                        22:57:49   Log-Likelihood:                         -87.985
# No. Observations:                  10   AIC:                                      180.0
# Df Residuals:                       8   BIC:                                      180.6
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...
